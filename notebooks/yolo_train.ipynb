# %%
import torch
from PIL import Image
from ultralytics import YOLO
import cv2

model = YOLO("/content/yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 247MB/s]

# %%
model.train(data="/content/train_cfg.yaml",
            model="/content/yolov8m.pt",
            patience=5,
            batch=16,
            save=True,
            verbose=True,
            project="hack_yolov8m",
            name="platform_detection"
            )
# Out:
# Ultralytics YOLOv8.0.216 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics.utils.plotting import Annotator

results = model("/content/dataset_yolo/obj_val_data/image530.jpg")

for r in results:

    annotator = Annotator(cv2.imread("/content/dataset_yolo/obj_val_data/image530.jpg"))

    boxes = r.boxes
    for box in boxes:
        print(box)
        b = box.xyxy[0]  # get box coordinates in (top, left, bottom, right) format
        c = box.cls
        annotator.box_label(b, model.names[int(c)])

img = annotator.result()
cv2.imshow(img)
# Out:
# image 1/1 /content/dataset_yolo/obj_val_data/image530.jpg: 640x640 1 Platform, 37.1ms
# Speed: 3.9ms preprocess, 37.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.8207], device='cuda:0')
# data: tensor([[175.2153, 296.2796, 539.8189, 406.3732,   0.8207,   0.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (720, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[357.5171, 351.3264, 364.6036, 110.0936]], device='cuda:0')
# xywhn: tensor([[0.4966, 0.4880, 0.5064, 0.1529]], device='cuda:0')
# xyxy: tensor([[175.2153, 296.2796, 539.8189, 406.3732]], device='cuda:0')
# xyxyn: tensor([[0.2434, 0.4115, 0.7497, 0.5644]], device='cuda:0')
# <PIL.Image.Image image mode=RGB size=720x720>
